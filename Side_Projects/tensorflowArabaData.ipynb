# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataframe = pd.read_excel("merc.xlsx")

# %%
dataframe.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataframe.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
sbn.distplot(dataframe["price"])
# Out:
# c:\Users\Öğrenci\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
dataframe.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
dataframe.corr()["price"].sort_values(ascending=False)
# Out:
# price         1.000000
# year          0.520712
# engineSize    0.516126
# tax           0.268717
# mpg          -0.438445
# mileage      -0.537214
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,8))
sbn.scatterplot(x="mileage",y="price", data = dataframe)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dataframe.sort_values("price",ascending=False).head(20)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
len(dataframe) * 0.01
# Out:
# 131.19

# %%
strippedDataFrame = dataframe.sort_values("price", ascending=False).iloc[131:]

# %%
strippedDataFrame
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11816  2003    650       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
plt.figure(figsize=(15,8))
sbn.distplot(strippedDataFrame["price"])
# Out:
# c:\Users\Öğrenci\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# DAHA NORMAL BİR DATA ELDE ETTİK EN MAX 130 VERİYİ SİLEREK

# %%
strippedDataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %% [markdown]
# 1970 VERİSİDE FAZLA UÇ NOKTADA. O YÜZDEN ONU DA ÇIKARIYORUZ

# %%
dataframe = strippedDataFrame

# %%
dataframe.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataframe = dataframe[dataframe.year != 1970]

# %%
dataframe.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %% [markdown]
# TRANSMISSION KISMI SAYISAL VERİ DEĞİL. O YÜZDEN O COLUMN ÇIKARIYORUZ

# %%
dataframe.head()
# Out:
#       year  price transmission  mileage  tax   mpg  engineSize
# 6177  2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779  2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191  2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727  2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814  2019  64999    Semi-Auto      119  145  40.9         3.0

# %%
dataframe = dataframe.drop("transmission",axis = 1)

# %%
dataframe
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 6177   2019  65990     5076  150  30.4         3.0
# 5779   2020  65990      999  145  28.0         4.0
# 3191   2020  65980     3999  145  28.0         4.0
# 4727   2019  65000     3398  145  27.2         4.0
# 8814   2019  64999      119  145  40.9         3.0
# ...     ...    ...      ...  ...   ...         ...
# 11549  2002   1495    13800  305  39.8         2.7
# 12594  2004   1495   119000  300  34.5         1.8
# 11765  2000   1490    87000  265  27.2         3.2
# 12008  2010   1350   116126  145  54.3         2.0
# 11816  2003    650   109090  235  40.0         1.4
#
# [12987 rows x 6 columns]
