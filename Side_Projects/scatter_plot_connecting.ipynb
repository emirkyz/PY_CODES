# %%
import numpy as np
import matplotlib.pyplot as plt
import random 

colors = ["b","g","r","c","m","y","k"]

print(colors)
#B = np.random.randint(-100,100, size=(10,10))
data=np.random.randint(-200,200,size=10)
# print(B)

X= np.random.randint(-170,170,size=10)
Y= np.random.randint(-170,170,size=10)


#X = np.sort(B[0,:])
#Y = np.sort(B[:,0])

tempX = np.array([])
tempY = np.array([])
temp_data = data

print(data)
print(X)
print(Y)
while (len(tempY) <= 10):
    tempX = np.array([])
    tempY = np.array([])
    for i in range(len(data)):
        
        for j in range(1,len(data)):  
            
            if (abs(temp_data[i] - temp_data[j])<= 20):
                tempX =np.append(tempX, (X[i],X[j]))
                tempY =np.append(tempY, (Y[i],Y[j]))
                #plt.plot(tempX[1:10],tempY[1:10])
                
              
                print(tempX)
                print(tempY)
                i+=1
            if(len(tempX) == 12):
                break
                
        plt.plot(tempX,tempY, color = random.choice(colors))
        if(len(tempX) == 12):
                break
                
                
                

       

    

plt.scatter(X, Y, s = 50)
plt.xlim([-200,200])
plt.ylim([-200,200])

for i, txt in enumerate(data):
    plt.annotate(txt, (X[i], Y[i]))
    
plt.show()
# Out:
# ['b', 'g', 'r', 'c', 'm', 'y', 'k']
# [  56  -24 -106  165   37  148  195  -60  -19  142]
# [ 25  30  30  58 -79 -79 134 168  -8  51]
# [  91  118  -82   -6   70 -151 -101   74  149  -88]
# [ 25. -79.]
# [91. 70.]
# [ 25. -79.  30.  -8.]
# [ 91.  70. 118. 149.]
# [ 25. -79.  30.  -8.  30.  30.]
# [ 91.  70. 118. 149. 118. 118.]
# [ 25. -79.  30.  -8.  30.  30.  30.  30.]
# [ 91.  70. 118. 149. 118. 118. -82. -82.]
# [ 25. -79.  30.  -8.  30.  30.  30.  30.  58.  58.]
# [ 91.  70. 118. 149. 118. 118. -82. -82.  -6.  -6.]
# [ 25. -79.  30.  -8.  30.  30.  30.  30.  58.  58. -79. -79.]
# [ 91.  70. 118. 149. 118. 118. -82. -82.  -6.  -6.  70.  70.]
